# %%
import pandas as pd

# %%
data = {
    "cars": ["camry", "civic", "optima"],
    "company" : ["toyota", 'honda', 'kia'],
    "country" : ["japan", 'japan', 'japan']
}

# %%
df = pd.DataFrame(data=data)

# %%
print(df)
