# %%
import pandas as pd

# %%
pd_objs = dir(pd)

# %%
for obj in pd_objs:
    if obj.startswith("D"):
        print(obj + " which is of type: ", type(obj))
# Out:
# DataFrame which is of type:  <class 'str'>
# DateOffset which is of type:  <class 'str'>
# DatetimeIndex which is of type:  <class 'str'>
# DatetimeTZDtype which is of type:  <class 'str'>

# %%
# pd.DataFrame
